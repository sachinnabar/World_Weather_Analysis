# mar del plata ar
# kerman ir
# nizhneyansk ru
# bhuban in
# avarua ck
# belushya guba ru
# charters towers au
# yulara au
# ushuaia ar
# saint andrews ca
# kargasok ru
# batagay ru
# kroya id
# halalo wf
# vaini to
# port alfred za
# inirida co
# faya td
# tuktoyaktuk ca
# bredasdorp za
# butaritari ki
# avarua ck
# paita pe
# bluff nz
# flin flon ca
# rawson ar
# havre-saint-pierre ca
# kodiak us
# thompson ca
# ushuaia ar
# taolanaro mg
# kodiak us
# hermanus za
# shingu jp
# busselton au
# rikitea pf
# miri my
# atuona pf
# butaritari ki
# kodiak us
# bluff nz
# lolua tv
# kudat my
# new norfolk au
# saskatoon ca
# joao pinheiro br
# qaanaaq gl
# vaitupu wf
# karratha au
# talnakh ru
# qingdao cn
# kismayo so
# henties bay na
# pangnirtung ca
# khatanga ru
# pevek ru
# vaini to
# hilo us
# chuy uy
# busselton au
# hithadhoo mv
# rikitea pf
# moen no
# pedernales do
# shetpe kz
# ancona it
# ushuaia ar
# castro cl
# mataura pf
# bolungarvik is
# rikitea pf
# coihaique cl
# vila do maio cv
# xichang cn
# georgetown sh
# leningradskiy ru
# muli mv
# essex ca
# ushuaia ar
# kapaa us
# georgetown sh
# cape town za
# nikolskoye ru
# cape town za
# hobart au
# hasaki jp
# qaanaaq gl
# ancud cl
# belushya guba ru
# taolanaro mg
# arraial do cabo br
# taolanaro mg
# amapa br
# carnarvon au
# simbach de
# tarbes fr
# georgetown sh
# busselton au
# saint-philippe re
# barentsburg sj
# husavik is
# taolanaro mg
# tarakan id
# key largo us
# sataua ws
# rikitea pf
# cabo san lucas mx
# makung tw
# dolbeau ca
# san patricio mx
# atbasar kz
# cabo san lucas mx
# faanui pf
# rikitea pf
# mataura pf
# rungata ki
# thompson ca
# margate za
# kaitangata nz
# punta arenas cl
# bluff nz
# guerrero negro mx
# punta arenas cl
# hermanus za
# lebu cl
# belmonte br
# albany au
# victoria sc
# nizhneyansk ru
# nyurba ru
# esperance au
# ilulissat gl
# beyneu kz
# lithakia gr
# spearfish us
# padang id
# the valley ai
# evensk ru
# vaini to
# grandview us
# new norfolk au
# byron bay au
# ahipara nz
# davila ph
# yomitan jp
# hobart au
# bahia blanca ar
# la macarena co
# kapaa us
# evensk ru
# inndyr no
# rikitea pf
# belushya guba ru
# lao cai vn
# gamba ga
# albany au
# leningradskiy ru
# tautira pf
# yerbogachen ru
# inongo cd
# bunia cd
# russellville us
# olafsvik is
# chuy uy
# hearst ca
# manggar id
# busselton au
# qaanaaq gl
# hasaki jp
# avera pf
# lebu cl
# port alfred za
# zaysan kz
# caratinga br
# hermanus za
# castro cl
# rikitea pf
# lebu cl
# avarua ck
# bambous virieux mu
# new norfolk au
# san quintin mx
# bluff nz
# valdivia cl
# punta arenas cl
# qaanaaq gl
# punta arenas cl
# busselton au
# santa rosa bo
# cherskiy ru
# hami cn
# illoqqortoormiut gl
# bredasdorp za
# cumberland us
# new norfolk au
# punta arenas cl
# riyadh sa
# jefferson city us
# jamestown sh
# bredasdorp za
# isiro cd
# conde br
# busselton au
# mezen ru
# rikitea pf
# bredasdorp za
# hasaki jp
# rikitea pf
# avarua ck
# inderborskiy kz
# rikitea pf
# sisimiut gl
# mahibadhoo mv
# gurupa br
# butaritari ki
# punta arenas cl
# muros es
# mmabatho za
# amderma ru
# halalo wf
# tokur ru
# vaini to
# rikitea pf
# obluche ru
# mataura pf
# ahuimanu us
# santa isabel do rio negro br
# hermanus za
# mys shmidta ru
# trenggalek id
# saskylakh ru
# tuktoyaktuk ca
# saskylakh ru
# vaini to
# lebu cl
# atuona pf
# kemin kg
# devyatka ru
# port alfred za
# iquique cl
# ancud cl
# halden no
# albany au
# barentsburg sj
# griffith au
# albany au
# san vicente ph
# kavaratti in
# canico pt
# kavieng pg
# luderitz na
# mataura pf
# ushuaia ar
# mataura pf
# georgetown sh
# barrow us
# tianpeng cn
# georgetown sh
# beloha mg
# rawah iq
# hithadhoo mv
# ahipara nz
# westport nz
# bluff nz
# dikson ru
# fortuna us
# jamestown sh
# kilindoni tz
# nemuro jp
# saldanha za
# iquique cl
# kahului us
# hermanus za
# killybegs ie
# banda aceh id
# saint-philippe re
# brandon us
# hilo us
# san cristobal ec
# castro cl
# ulaangom mn
# busselton au
# hobart au
# ushuaia ar
# khatanga ru
# anuradhapura lk
# vila franca do campo pt
# coquimbo cl
# bredasdorp za
# pontianak id
# belushya guba ru
# ostrovnoy ru
# hobart au
# busselton au
# port macquarie au
# quesnel ca
# busselton au
# gornyye klyuchi ru
# vao nc
# tubuala pa
# ajaccio fr
# thompson ca
# aberystwyth gb
# baykit ru
# rikitea pf
# arraial do cabo br
# nikolskoye ru
# siofok hu
# rosarito mx
# grand river south east mu
# avarua ck
# abu kamal sy
# yei sd
# laguna br
# nikolskoye ru
# lebu cl
# ust-nera ru
# albany au
# cape town za
# busselton au
# maceio br
# mataura pf
# wattegama lk
# taolanaro mg
# longyearbyen sj
# ushuaia ar
# gamba ga
# georgetown sh
# mataura pf
# mutoko zw
# upernavik gl
# bredasdorp za
# tasiilaq gl
# turan ru
# mataura pf
# vardo no
# punta arenas cl
# bambous virieux mu
# bredasdorp za
# pisco pe
# thompson ca
# luderitz na
# saint-louis sn
# kailua us
# huilong cn
# rikitea pf
# boa vista br
# hualmay pe
# tilichiki ru
# maldonado uy
# pemangkat id
# esperance au
# busselton au
# busselton au
# petauke zm
# jamestown sh
# hervey bay au
# attawapiskat ca
# husavik is
# avarua ck
# port blair in
# hunza pk
# dwarka in
# punta arenas cl
# halifax ca
# mataura pf
# emba kz
# chibuto mz
# yenagoa ng
# buraydah sa
# port elizabeth za
# ushuaia ar
# grand river south east mu
# esperance au
# busselton au
# atuona pf
# ushuaia ar
# albany au
# georgetown gy
# havoysund no
# cape town za
# port alfred za
# hobart au
# tahoua ne
# mataura pf
# langsa id
# tabuk sa
# gunjur gm
# constitucion cl
# severo-kurilsk ru
# provideniya ru
# jamestown sh
# chokurdakh ru
# khatanga ru
# linshu cn
# saskylakh ru
# hobart au
# amderma ru
# castanos mx
# marystown ca
# tasiilaq gl
# hithadhoo mv
# shingu jp
# kapaa us
# avarua ck
# kawambwa zm
# rikitea pf
# barentsburg sj
# busselton au
# hermanus za
# minsk by
# ryotsu jp
# rikitea pf
# ribeira grande pt
# saint george bm
# kodiak us
# busselton au
# kidal ml
# mataura pf
# bandarbeyla so
# attawapiskat ca
# manitouwadge ca
# launceston au
# ushuaia ar
# punta arenas cl
# puerto ayora ec
# punta arenas cl
# iqaluit ca
# port blair in
# bluff nz
# sao filipe cv
# kavaratti in
# reo bf
# port blair in
# nistoresti ro
# lompoc us
# faya td
# carnarvon au
# rikitea pf
# dalaba gn
# attawapiskat ca
# pecos us
# atuona pf
# new bern us
# taolanaro mg
# wanning cn
# saint george bm
# dingle ie
# carutapera br

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | isabela
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | holetown
# Processing Record 7 of Set 1 | camacha
# Processing Record 8 of Set 1 | mazagao
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | imisli
# City not found. Skipping...
# Processing Record 13 of Set 1 | antofagasta
# Processing Record 14 of Set 1 | sahrak
# City not found. Skipping...
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | marsh harbour
# Processing Record 18 of Set 1 | beyneu
# Processing Record 19 of Set 1 | comodoro rivadavia
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | poysdorf
# Processing Record 24 of Set 1 | san quintin
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | ouesso
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | sosnovo-ozerskoye
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | jand
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | fort beaufort
# Processing Record 38 of Set 1 | lalibela
# Processing Record 39 of Set 1 | marshalltown
# Processing Record 40 of Set 1 | broken hill
# Processing Record 41 of Set 1 | aleksandrov gay
# Processing Record 42 of Set 1 | qaqortoq
# Processing Record 43 of Set 1 | sukhinichi
# Processing Record 44 of Set 1 | ambilobe
# Processing Record 45 of Set 1 | las vegas
# Processing Record 46 of Set 1 | biu
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | lasa
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 2 | san joaquin
# Processing Record 2 of Set 2 | lazaro cardenas
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | marzuq
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | arkhangelos
# City not found. Skipping...
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | moberly
# Processing Record 10 of Set 2 | lorengau
# Processing Record 11 of Set 2 | boyolangu
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | kasongo-lunda
# Processing Record 15 of Set 2 | vangaindrano
# Processing Record 16 of Set 2 | central point
# Processing Record 17 of Set 2 | faya
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | monastyrshchina
# Processing Record 20 of Set 2 | ambanja
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 2 | necochea
# Processing Record 24 of Set 2 | tres barras
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 2 | casper
# Processing Record 28 of Set 2 | najran
# Processing Record 29 of Set 2 | nioro
# Processing Record 30 of Set 2 | bambanglipuro
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 2 | puerto carreno
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | lagunas
# Processing Record 43 of Set 2 | kaka
# Processing Record 44 of Set 2 | cantaura
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | zavitinsk
# Processing Record 48 of Set 2 | vaini
# Processing Record 49 of Set 2 | stephenville
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | irkutsk
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | boa vista
# Processing Record 4 of Set 3 | teshie
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | ballina
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | juneau
# Processing Record 9 of Set 3 | rochegda
# Processing Record 10 of Set 3 | sola
# Processing Record 11 of Set 3 | tayu
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | abu dhabi
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | sibiti
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 3 | grindavik
# Processing Record 19 of Set 3 | soyo
# Processing Record 20 of Set 3 | andenes
# Processing Record 21 of Set 3 | kenai
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | sinop
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | nenjiang
# Processing Record 26 of Set 3 | noumea
# Processing Record 27 of Set 3 | turukhansk
# Processing Record 28 of Set 3 | vestmannaeyjar
# Processing Record 29 of Set 3 | vinh
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | indian head
# Processing Record 32 of Set 3 | hithadhoo
# Processing Record 33 of Set 3 | sur
# Processing Record 34 of Set 3 | chernushka
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | hilo
# Processing Record 38 of Set 3 | hambantota
# Processing Record 39 of Set 3 | kapaa
# Processing Record 40 of Set 3 | makakilo city
# Processing Record 41 of Set 3 | ondangwa
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | vao
# Processing Record 44 of Set 3 | alofi
# Processing Record 45 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record 46 of Set 3 | klyuchi
# Processing Record 47 of Set 3 | nyurba
# Processing Record 48 of Set 3 | nicoya
# Processing Record 49 of Set 3 | manacapuru
# Processing Record 50 of Set 3 | verkhoyansk
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | zhiryatino
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | aklavik
# Processing Record 8 of Set 4 | cayenne
# Processing Record 9 of Set 4 | voh
# Processing Record 10 of Set 4 | novoagansk
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | butaritari
# Processing Record 15 of Set 4 | lavrentiya
# Processing Record 16 of Set 4 | mayo
# Processing Record 17 of Set 4 | benton harbor
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | muros
# Processing Record 20 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 4 | poso
# Processing Record 22 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 23 of Set 4 | nome
# Processing Record 24 of Set 4 | acarau
# Processing Record 25 of Set 4 | vrangel
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | mao
# Processing Record 29 of Set 4 | provideniya
# Processing Record 30 of Set 4 | zlatoust
# Processing Record 31 of Set 4 | north myrtle beach
# Processing Record 32 of Set 4 | ilulissat
# Processing Record 33 of Set 4 | balkanabat
# Processing Record 34 of Set 4 | playa del carmen
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | luganville
# Processing Record 37 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 4 | roseburg
# Processing Record 39 of Set 4 | robertsport
# Processing Record 40 of Set 4 | jining
# Processing Record 41 of Set 4 | shimoda
# Processing Record 42 of Set 4 | bathsheba
# Processing Record 43 of Set 4 | fortuna
# Processing Record 44 of Set 4 | nabire
# Processing Record 45 of Set 4 | takoradi
# Processing Record 46 of Set 4 | uvira
# Processing Record 47 of Set 4 | selma
# Processing Record 48 of Set 4 | kendallville
# Processing Record 49 of Set 4 | plettenberg bay
# Processing Record 50 of Set 4 | richards bay
# Processing Record 1 of Set 5 | diu
# Processing Record 2 of Set 5 | kirakira
# Processing Record 3 of Set 5 | bucerias
# Processing Record 4 of Set 5 | portland
# Processing Record 5 of Set 5 | heiligenhafen
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | pampa
# Processing Record 8 of Set 5 | tura
# Processing Record 9 of Set 5 | beidao
# Processing Record 10 of Set 5 | pemangkat
# Processing Record 11 of Set 5 | deputatskiy
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | rio gallegos
# Processing Record 14 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | wageningen
# Processing Record 17 of Set 5 | victoria
# Processing Record 18 of Set 5 | yulin
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | hervey bay
# Processing Record 21 of Set 5 | port hardy
# Processing Record 22 of Set 5 | norman wells
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | caravelas
# Processing Record 25 of Set 5 | boffa
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | tuktoyaktuk
# Processing Record 28 of Set 5 | tecate
# Processing Record 29 of Set 5 | yulara
# Processing Record 30 of Set 5 | arona
# Processing Record 31 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 5 | boves
# Processing Record 33 of Set 5 | lewiston
# Processing Record 34 of Set 5 | kristianstad
# Processing Record 35 of Set 5 | palmer
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | kambove
# Processing Record 39 of Set 5 | doctor phillips
# Processing Record 40 of Set 5 | nieuw amsterdam
# Processing Record 41 of Set 5 | mocajuba
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | hasaki
# Processing Record 45 of Set 5 | ojinaga
# Processing Record 46 of Set 5 | celestun
# Processing Record 47 of Set 5 | ayan
# Processing Record 48 of Set 5 | cherskiy
# Processing Record 49 of Set 5 | evensk
# Processing Record 50 of Set 5 | tabou
# Processing Record 1 of Set 6 | limbang
# Processing Record 2 of Set 6 | adur
# Processing Record 3 of Set 6 | rettikhovka
# Processing Record 4 of Set 6 | broome
# Processing Record 5 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 6 | rocha
# Processing Record 7 of Set 6 | mandera
# Processing Record 8 of Set 6 | melito di porto salvo
# Processing Record 9 of Set 6 | san cristobal
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | clyde river
# Processing Record 13 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 6 | kruisfontein
# Processing Record 15 of Set 6 | hami
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | praia
# Processing Record 18 of Set 6 | luderitz
# Processing Record 19 of Set 6 | koumac
# Processing Record 20 of Set 6 | kerman
# Processing Record 21 of Set 6 | karratha
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | chulym
# Processing Record 24 of Set 6 | ahipara
# Processing Record 25 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | san lorenzo
# Processing Record 28 of Set 6 | teya
# Processing Record 29 of Set 6 | sorkjosen
# Processing Record 30 of Set 6 | port-gentil
# Processing Record 31 of Set 6 | agadez
# Processing Record 32 of Set 6 | selenice
# Processing Record 33 of Set 6 | mana
# Processing Record 34 of Set 6 | ixtapa
# Processing Record 35 of Set 6 | hangu
# Processing Record 36 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 6 | saint george
# Processing Record 38 of Set 6 | zhezkazgan
# Processing Record 39 of Set 6 | centerville
# Processing Record 40 of Set 6 | olafsvik
# Processing Record 41 of Set 6 | ygatimi
# Processing Record 42 of Set 6 | ramhormoz
# Processing Record 43 of Set 6 | cockburn town
# Processing Record 44 of Set 6 | kasempa
# Processing Record 45 of Set 6 | conceicao do araguaia
# Processing Record 46 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 6 | mikhaylovka
# Processing Record 48 of Set 6 | fare
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | kulhudhuffushi
# Processing Record 1 of Set 7 | tuy hoa
# Processing Record 2 of Set 7 | formosa
# Processing Record 3 of Set 7 | joshimath
# Processing Record 4 of Set 7 | crateus
# Processing Record 5 of Set 7 | chokurdakh
# Processing Record 6 of Set 7 | bud
# Processing Record 7 of Set 7 | kavaratti
# Processing Record 8 of Set 7 | severo-yeniseyskiy
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 7 | urgut
# Processing Record 12 of Set 7 | semnan
# Processing Record 13 of Set 7 | konigslutter
# City not found. Skipping...
# Processing Record 14 of Set 7 | pochutla
# Processing Record 15 of Set 7 | bhuban
# Processing Record 16 of Set 7 | charters towers
# Processing Record 17 of Set 7 | saint andrews
# Processing Record 18 of Set 7 | kargasok
# Processing Record 19 of Set 7 | batagay
# Processing Record 20 of Set 7 | kroya
# Processing Record 21 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 7 | inirida
# Processing Record 23 of Set 7 | paita
# Processing Record 24 of Set 7 | flin flon
# Processing Record 25 of Set 7 | rawson
# Processing Record 26 of Set 7 | havre-saint-pierre
# Processing Record 27 of Set 7 | shingu
# Processing Record 28 of Set 7 | miri
# Processing Record 29 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 7 | kudat
# Processing Record 31 of Set 7 | saskatoon
# Processing Record 32 of Set 7 | joao pinheiro
# Processing Record 33 of Set 7 | talnakh
# Processing Record 34 of Set 7 | qingdao
# Processing Record 35 of Set 7 | kismayo
# Processing Record 36 of Set 7 | henties bay
# Processing Record 37 of Set 7 | pangnirtung
# Processing Record 38 of Set 7 | moen
# Processing Record 39 of Set 7 | pedernales
# Processing Record 40 of Set 7 | shetpe
# Processing Record 41 of Set 7 | ancona
# Processing Record 42 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 7 | coihaique
# Processing Record 44 of Set 7 | vila do maio
# Processing Record 45 of Set 7 | xichang
# Processing Record 46 of Set 7 | muli
# Processing Record 47 of Set 7 | essex
# Processing Record 48 of Set 7 | ancud
# Processing Record 49 of Set 7 | amapa
# Processing Record 50 of Set 7 | simbach
# Processing Record 1 of Set 8 | tarbes
# Processing Record 2 of Set 8 | husavik
# Processing Record 3 of Set 8 | tarakan
# Processing Record 4 of Set 8 | key largo
# Processing Record 5 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 8 | makung
# City not found. Skipping...
# Processing Record 7 of Set 8 | atbasar
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | guerrero negro
# Processing Record 10 of Set 8 | belmonte
# Processing Record 11 of Set 8 | lithakia
# Processing Record 12 of Set 8 | spearfish
# Processing Record 13 of Set 8 | padang
# Processing Record 14 of Set 8 | the valley
# Processing Record 15 of Set 8 | grandview
# Processing Record 16 of Set 8 | byron bay
# Processing Record 17 of Set 8 | davila
# Processing Record 18 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 19 of Set 8 | bahia blanca
# Processing Record 20 of Set 8 | la macarena
# Processing Record 21 of Set 8 | inndyr
# Processing Record 22 of Set 8 | lao cai
# Processing Record 23 of Set 8 | gamba
# Processing Record 24 of Set 8 | tautira
# Processing Record 25 of Set 8 | yerbogachen
# Processing Record 26 of Set 8 | inongo
# Processing Record 27 of Set 8 | bunia
# Processing Record 28 of Set 8 | russellville
# Processing Record 29 of Set 8 | hearst
# Processing Record 30 of Set 8 | manggar
# Processing Record 31 of Set 8 | zaysan
# Processing Record 32 of Set 8 | caratinga
# Processing Record 33 of Set 8 | valdivia
# Processing Record 34 of Set 8 | santa rosa
# Processing Record 35 of Set 8 | cumberland
# Processing Record 36 of Set 8 | riyadh
# Processing Record 37 of Set 8 | jefferson city
# Processing Record 38 of Set 8 | isiro
# Processing Record 39 of Set 8 | avaton
# Processing Record 40 of Set 8 | airai
# Processing Record 41 of Set 8 | fairview
# Processing Record 42 of Set 8 | areia branca
# Processing Record 43 of Set 8 | collie
# Processing Record 44 of Set 8 | huesca
# Processing Record 45 of Set 8 | ribeira grande
# Processing Record 46 of Set 8 | yar-sale
# Processing Record 47 of Set 8 | san jose de las lajas
# Processing Record 48 of Set 8 | alice springs
# Processing Record 49 of Set 8 | pauini
# Processing Record 50 of Set 8 | vallenar
# Processing Record 1 of Set 9 | soverato
# Processing Record 2 of Set 9 | chardara
# Processing Record 3 of Set 9 | nisia floresta
# Processing Record 4 of Set 9 | ilebo
# Processing Record 5 of Set 9 | araouane
# Processing Record 6 of Set 9 | coahuayana
# Processing Record 7 of Set 9 | vanimo
# Processing Record 8 of Set 9 | nakatunguru
# Processing Record 9 of Set 9 | namibe
# Processing Record 10 of Set 9 | gondar
# Processing Record 11 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 13 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 14 of Set 9 | bilibino
# Processing Record 15 of Set 9 | kazachinskoye
# Processing Record 16 of Set 9 | dunedin
# Processing Record 17 of Set 9 | erdenet
# Processing Record 18 of Set 9 | villacarrillo
# Processing Record 19 of Set 9 | medicine hat
# Processing Record 20 of Set 9 | sao geraldo do araguaia
# Processing Record 21 of Set 9 | melchor de mencos
# Processing Record 22 of Set 9 | tingo maria
# Processing Record 23 of Set 9 | roswell
# Processing Record 24 of Set 9 | tilichiki
# Processing Record 25 of Set 9 | asau
# Processing Record 26 of Set 9 | talah
# City not found. Skipping...
# Processing Record 27 of Set 9 | korla
# Processing Record 28 of Set 9 | merauke
# Processing Record 29 of Set 9 | punata
# Processing Record 30 of Set 9 | luau
# Processing Record 31 of Set 9 | quzhou
# Processing Record 32 of Set 9 | sao gabriel da cachoeira
# Processing Record 33 of Set 9 | nsoko
# Processing Record 34 of Set 9 | port augusta
# Processing Record 35 of Set 9 | bardiyah
# Processing Record 36 of Set 9 | bushehr
# Processing Record 37 of Set 9 | imeni poliny osipenko
# Processing Record 38 of Set 9 | nelson bay
# Processing Record 39 of Set 9 | sukhoverkovo
# City not found. Skipping...
# Processing Record 40 of Set 9 | olinda
# Processing Record 41 of Set 9 | biskamzha
# Processing Record 42 of Set 9 | kangaatsiaq
# Processing Record 43 of Set 9 | dolinsk
# Processing Record 44 of Set 9 | te anau
# Processing Record 45 of Set 9 | natal
# Processing Record 46 of Set 9 | karia
# Processing Record 47 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 48 of Set 9 | birnin kebbi
# Processing Record 49 of Set 9 | ambulu
# Processing Record 50 of Set 9 | gornyy
# Processing Record 1 of Set 10 | pyinmana
# Processing Record 2 of Set 10 | yuryuzan
# Processing Record 3 of Set 10 | macklin
# Processing Record 4 of Set 10 | omboue
# Processing Record 5 of Set 10 | baculin
# Processing Record 6 of Set 10 | faribault
# Processing Record 7 of Set 10 | mahibadhoo
# Processing Record 8 of Set 10 | farafangana
# Processing Record 9 of Set 10 | pitimbu
# Processing Record 10 of Set 10 | lembeni
# Processing Record 11 of Set 10 | san ramon de la nueva oran
# Processing Record 12 of Set 10 | conde
# Processing Record 13 of Set 10 | mezen
# Processing Record 14 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 15 of Set 10 | sisimiut
# Processing Record 16 of Set 10 | gurupa
# Processing Record 17 of Set 10 | mmabatho
# Processing Record 18 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 10 | tokur
# Processing Record 20 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 21 of Set 10 | ahuimanu
# Processing Record 22 of Set 10 | santa isabel do rio negro
# Processing Record 23 of Set 10 | trenggalek
# Processing Record 24 of Set 10 | kemin
# Processing Record 25 of Set 10 | devyatka
# City not found. Skipping...
# Processing Record 26 of Set 10 | iquique
# Processing Record 27 of Set 10 | halden
# Processing Record 28 of Set 10 | griffith
# Processing Record 29 of Set 10 | san vicente
# Processing Record 30 of Set 10 | canico
# Processing Record 31 of Set 10 | tianpeng
# Processing Record 32 of Set 10 | beloha
# Processing Record 33 of Set 10 | rawah
# Processing Record 34 of Set 10 | westport
# Processing Record 35 of Set 10 | kilindoni
# Processing Record 36 of Set 10 | nemuro
# Processing Record 37 of Set 10 | killybegs
# Processing Record 38 of Set 10 | banda aceh
# Processing Record 39 of Set 10 | brandon
# Processing Record 40 of Set 10 | ulaangom
# Processing Record 41 of Set 10 | anuradhapura
# Processing Record 42 of Set 10 | coquimbo
# Processing Record 43 of Set 10 | pontianak
# Processing Record 44 of Set 10 | ostrovnoy
# Processing Record 45 of Set 10 | port macquarie
# Processing Record 46 of Set 10 | quesnel
# Processing Record 47 of Set 10 | gornyye klyuchi
# Processing Record 48 of Set 10 | tubuala
# Processing Record 49 of Set 10 | ajaccio
# Processing Record 50 of Set 10 | aberystwyth
# Processing Record 1 of Set 11 | baykit
# Processing Record 2 of Set 11 | siofok
# Processing Record 3 of Set 11 | rosarito
# Processing Record 4 of Set 11 | abu kamal
# Processing Record 5 of Set 11 | yei
# Processing Record 6 of Set 11 | laguna
# Processing Record 7 of Set 11 | ust-nera
# Processing Record 8 of Set 11 | maceio
# Processing Record 9 of Set 11 | wattegama
# Processing Record 10 of Set 11 | mutoko
# Processing Record 11 of Set 11 | turan
# Processing Record 12 of Set 11 | saint-louis
# Processing Record 13 of Set 11 | kailua
# Processing Record 14 of Set 11 | huilong
# Processing Record 15 of Set 11 | hualmay
# Processing Record 16 of Set 11 | maldonado
# Processing Record 17 of Set 11 | petauke
# Processing Record 18 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 19 of Set 11 | dwarka
# Processing Record 20 of Set 11 | halifax
# Processing Record 21 of Set 11 | emba
# Processing Record 22 of Set 11 | chibuto
# Processing Record 23 of Set 11 | yenagoa
# Processing Record 24 of Set 11 | buraydah
# Processing Record 25 of Set 11 | havoysund
# Processing Record 26 of Set 11 | tahoua
# Processing Record 27 of Set 11 | langsa
# Processing Record 28 of Set 11 | tabuk
# Processing Record 29 of Set 11 | gunjur
# Processing Record 30 of Set 11 | constitucion
# Processing Record 31 of Set 11 | linshu
# City not found. Skipping...
# Processing Record 32 of Set 11 | castanos
# Processing Record 33 of Set 11 | marystown
# Processing Record 34 of Set 11 | novotroitsk
# Processing Record 35 of Set 11 | chipata
# Processing Record 36 of Set 11 | mitsamiouli
# Processing Record 37 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 38 of Set 11 | emporia
# Processing Record 39 of Set 11 | kiama
# Processing Record 40 of Set 11 | pacific grove
# Processing Record 41 of Set 11 | verkhneyarkeyevo
# Processing Record 42 of Set 11 | vila velha
# Processing Record 43 of Set 11 | talas
# Processing Record 44 of Set 11 | grand gaube
# Processing Record 45 of Set 11 | poum
# Processing Record 46 of Set 11 | swan hill
# Processing Record 47 of Set 11 | rzhyshchiv
# Processing Record 48 of Set 11 | boissevain
# Processing Record 49 of Set 11 | matagami
# Processing Record 50 of Set 11 | yakeshi
# Processing Record 1 of Set 12 | kisangani
# Processing Record 2 of Set 12 | chulumani
# Processing Record 3 of Set 12 | kudahuvadhoo
# Processing Record 4 of Set 12 | gull lake
# Processing Record 5 of Set 12 | bourail
# Processing Record 6 of Set 12 | waingapu
# Processing Record 7 of Set 12 | xifeng
# Processing Record 8 of Set 12 | parabel
# Processing Record 9 of Set 12 | hargeysa
# Processing Record 10 of Set 12 | marawi
# Processing Record 11 of Set 12 | lagoa
# Processing Record 12 of Set 12 | knysna
# Processing Record 13 of Set 12 | mishkino
# Processing Record 14 of Set 12 | cadereyta
# Processing Record 15 of Set 12 | umba
# Processing Record 16 of Set 12 | tetouan
# Processing Record 17 of Set 12 | isetskoye
# Processing Record 18 of Set 12 | zaykovo
# Processing Record 19 of Set 12 | bonthe
# Processing Record 20 of Set 12 | ziarat
# Processing Record 21 of Set 12 | nazret
# Processing Record 22 of Set 12 | dickinson
# Processing Record 23 of Set 12 | mayahi
# Processing Record 24 of Set 12 | belyy yar
# Processing Record 25 of Set 12 | leshukonskoye
# Processing Record 26 of Set 12 | macapa
# Processing Record 27 of Set 12 | sangar
# Processing Record 28 of Set 12 | bima
# Processing Record 29 of Set 12 | pokrovsk
# Processing Record 30 of Set 12 | namatanai
# Processing Record 31 of Set 12 | altay
# Processing Record 32 of Set 12 | baruun-urt
# Processing Record 33 of Set 12 | do gonbadan
# Processing Record 34 of Set 12 | newcastle
# Processing Record 35 of Set 12 | kang
# Processing Record 36 of Set 12 | cosoleacaque
# Processing Record 37 of Set 12 | lilongwe
# Processing Record 38 of Set 12 | mercedes
# Processing Record 39 of Set 12 | milkovo
# Processing Record 40 of Set 12 | fort frances
# Processing Record 41 of Set 12 | marabba
# Processing Record 42 of Set 12 | meiganga
# Processing Record 43 of Set 12 | ponta delgada
# Processing Record 44 of Set 12 | srednekolymsk
# Processing Record 45 of Set 12 | lima
# Processing Record 46 of Set 12 | buchanan
# Processing Record 47 of Set 12 | klaksvik
# Processing Record 48 of Set 12 | krasnoselkup
# Processing Record 49 of Set 12 | bonfim
# Processing Record 50 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 13 | kardla
# Processing Record 2 of Set 13 | hamza
# Processing Record 3 of Set 13 | fairbanks
# Processing Record 4 of Set 13 | rio grande
# Processing Record 5 of Set 13 | valparaiso
# Processing Record 6 of Set 13 | baker city
# Processing Record 7 of Set 13 | dallas
# Processing Record 8 of Set 13 | vidim
# Processing Record 9 of Set 13 | mount isa
# Processing Record 10 of Set 13 | mandalgovi
# Processing Record 11 of Set 13 | kalabo
# Processing Record 12 of Set 13 | arambagh
# Processing Record 13 of Set 13 | homer
# Processing Record 14 of Set 13 | vohibinany
# Processing Record 15 of Set 13 | tuatapere
# Processing Record 16 of Set 13 | valparai
# Processing Record 17 of Set 13 | gasa
# Processing Record 18 of Set 13 | acandi
# Processing Record 19 of Set 13 | jalu
# Processing Record 20 of Set 13 | sao felix do xingu
# Processing Record 21 of Set 13 | tarko-sale
# Processing Record 22 of Set 13 | goderich
# Processing Record 23 of Set 13 | cabo rojo
# Processing Record 24 of Set 13 | kwekwe
# Processing Record 25 of Set 13 | jiayuguan
# Processing Record 26 of Set 13 | cabedelo
# Processing Record 27 of Set 13 | haines junction
# Processing Record 28 of Set 13 | wajir
# Processing Record 29 of Set 13 | bossangoa
# Processing Record 30 of Set 13 | tiznit
# Processing Record 31 of Set 13 | roebourne
# Processing Record 32 of Set 13 | lufilufi
# Processing Record 33 of Set 13 | kaduy
# Processing Record 34 of Set 13 | narsaq
# Processing Record 35 of Set 13 | waharoa
# Processing Record 36 of Set 13 | zyryanka
# Processing Record 37 of Set 13 | diego de almagro
# Processing Record 38 of Set 13 | itarema
# Processing Record 39 of Set 13 | luena
# Processing Record 40 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 13 | cartagena
# Processing Record 42 of Set 13 | saint-denis
# Processing Record 43 of Set 13 | pangai
# Processing Record 44 of Set 13 | hokitika
# Processing Record 45 of Set 13 | kasama
# Processing Record 46 of Set 13 | wynyard
# Processing Record 47 of Set 13 | alugan
# Processing Record 48 of Set 13 | katha
# City not found. Skipping...
# Processing Record 49 of Set 13 | kysyl-syr
# Processing Record 50 of Set 13 | jinchang
# Processing Record 1 of Set 14 | punta gorda
# Processing Record 2 of Set 14 | uppsala
# Processing Record 3 of Set 14 | ratlam
# Processing Record 4 of Set 14 | booue
# Processing Record 5 of Set 14 | santona
# Processing Record 6 of Set 14 | dingle
# Processing Record 7 of Set 14 | peniche
# Processing Record 8 of Set 14 | chapais
# Processing Record 9 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 10 of Set 14 | san rafael
# Processing Record 11 of Set 14 | rockport
# Processing Record 12 of Set 14 | kutum
# Processing Record 13 of Set 14 | jinxiang
# Processing Record 14 of Set 14 | lahij
# Processing Record 15 of Set 14 | batagay-alyta
# Processing Record 16 of Set 14 | revda
# Processing Record 17 of Set 14 | usakos
# Processing Record 18 of Set 14 | alto araguaia
# Processing Record 19 of Set 14 | buala
# Processing Record 20 of Set 14 | mahebourg
# Processing Record 21 of Set 14 | belur
# Processing Record 22 of Set 14 | codrington
# Processing Record 23 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 25 of Set 14 | nekhayevskiy
# Processing Record 26 of Set 14 | puksoozero
# Processing Record 27 of Set 14 | northam
# Processing Record 28 of Set 14 | kautokeino
# Processing Record 29 of Set 14 | njombe
# Processing Record 30 of Set 14 | alberdi
# Processing Record 31 of Set 14 | akonolinga
# Processing Record 32 of Set 14 | selkirk
# Processing Record 33 of Set 14 | viedma
# Processing Record 34 of Set 14 | naantali
# Processing Record 35 of Set 14 | egvekinot
# Processing Record 36 of Set 14 | birao
# Processing Record 37 of Set 14 | hvolsvollur
# Processing Record 38 of Set 14 | cairns
# Processing Record 39 of Set 14 | yumen
# Processing Record 40 of Set 14 | belaya gora
# Processing Record 41 of Set 14 | pinega
# Processing Record 42 of Set 14 | devils lake
# Processing Record 43 of Set 14 | hirara
# Processing Record 44 of Set 14 | ocampo
# Processing Record 45 of Set 14 | los llanos de aridane
# Processing Record 46 of Set 14 | ust-charyshskaya pristan
# Processing Record 47 of Set 14 | loandjili
# Processing Record 48 of Set 14 | diamantino
# Processing Record 49 of Set 14 | nassau
# Processing Record 50 of Set 14 | ayagoz
# Processing Record 1 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 15 | aykhal
# Processing Record 3 of Set 15 | christchurch
# Processing Record 4 of Set 15 | yurimaguas
# Processing Record 5 of Set 15 | mayna
# Processing Record 6 of Set 15 | taoudenni
# Processing Record 7 of Set 15 | darnah
# Processing Record 8 of Set 15 | masallatah
# Processing Record 9 of Set 15 | porto velho
# Processing Record 10 of Set 15 | neuquen
# Processing Record 11 of Set 15 | soderhamn
# Processing Record 12 of Set 15 | constanza
# Processing Record 13 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 15 | killarney
# Processing Record 15 of Set 15 | gambela
# Processing Record 16 of Set 15 | adrar
# Processing Record 17 of Set 15 | rakaia
# Processing Record 18 of Set 15 | kirovskiy
# Processing Record 19 of Set 15 | west bay
# Processing Record 20 of Set 15 | lexington
# Processing Record 21 of Set 15 | imbituba
# Processing Record 22 of Set 15 | mount pleasant
# Processing Record 23 of Set 15 | saint-jean-de-dieu
# City not found. Skipping...
# Processing Record 24 of Set 15 | chara
# Processing Record 25 of Set 15 | windhoek
# Processing Record 26 of Set 15 | nuuk
# Processing Record 27 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 28 of Set 15 | aanekoski
# Processing Record 29 of Set 15 | sinnamary
# Processing Record 30 of Set 15 | magadan
# Processing Record 31 of Set 15 | pasinler
# Processing Record 32 of Set 15 | novyy urengoy
# Processing Record 33 of Set 15 | fuerte olimpo
# Processing Record 34 of Set 15 | bereda
# Processing Record 35 of Set 15 | fairmont
# Processing Record 36 of Set 15 | taldan
# Processing Record 37 of Set 15 | solnechnyy
# Processing Record 38 of Set 15 | rancho palos verdes
# Processing Record 39 of Set 15 | mahajanga
# Processing Record 40 of Set 15 | ranong
# Processing Record 41 of Set 15 | chicama
# Processing Record 42 of Set 15 | west plains
# Processing Record 43 of Set 15 | hasilpur
# Processing Record 44 of Set 15 | abnub
# Processing Record 45 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 15 | amahai
# Processing Record 47 of Set 15 | budhlada
# Processing Record 48 of Set 15 | gat
# Processing Record 49 of Set 15 | saint-georges
# Processing Record 50 of Set 15 | magway
# Processing Record 1 of Set 16 | terney
# Processing Record 2 of Set 16 | praia da vitoria
# Processing Record 3 of Set 16 | vila
# Processing Record 4 of Set 16 | prado
# Processing Record 5 of Set 16 | paamiut
# Processing Record 6 of Set 16 | ayr
# Processing Record 7 of Set 16 | khonsa
# Processing Record 8 of Set 16 | talara
# Processing Record 9 of Set 16 | san jose
# Processing Record 10 of Set 16 | malkangiri
# Processing Record 11 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 16 | gavrilovka vtoraya
# Processing Record 13 of Set 16 | manokwari
# Processing Record 14 of Set 16 | dunmore town
# Processing Record 15 of Set 16 | barkhan
# Processing Record 16 of Set 16 | kawambwa
# Processing Record 17 of Set 16 | minsk
# Processing Record 18 of Set 16 | ryotsu
# Processing Record 19 of Set 16 | kidal
# Processing Record 20 of Set 16 | bandarbeyla
# Processing Record 21 of Set 16 | manitouwadge
# Processing Record 22 of Set 16 | launceston
# Processing Record 23 of Set 16 | reo
# Processing Record 24 of Set 16 | nistoresti
# Processing Record 25 of Set 16 | lompoc
# Processing Record 26 of Set 16 | dalaba
# Processing Record 27 of Set 16 | pecos
# Processing Record 28 of Set 16 | new bern
# Processing Record 29 of Set 16 | wanning
# Processing Record 30 of Set 16 | carutapera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -43.65,
#   'Humidity': 100,
#   'Cloudiness': 58,
#   'Wind Speed': 4.36,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 79.21,
#   'Humidity': 71,
#   'Cloudiness': 66,
#   'Wind Speed': 17.92,
#   'Country': 'PF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Isabela',
#   'Lat': 6.7085,
#   'Lng': 121.9711,
#   'Max Temp': 77.05,
#   'Humidity': 88,
#   'Cloudiness': 89,
#   'Wind Speed': 4.88,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 56.26,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 76.06,
#   'Humidity': 75,
#   'Cloudiness': 92,
#   'Wind Speed': 16.13,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Holetown',
#   'Lat': 13.1867,
#   'Lng': -59.6381,
#   'Max Temp': 79.36,
#   'Humidity': 80,
#   'Cloudiness': 80,
#   'Wind Speed': 19.35,
#   'Country': 'BB',
#   'Current Description': 'broken clouds'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 61.54,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'PT',
#   'Current Description': 'drizzle'},
#  {'City': 'Mazagao',
#   'Lat': -0.115,
#   'Lng': -51.2894,
#   'Max Temp': 86.05,
#   'Humidity': 74,
#   'Cloudiness': 58,
#   'Wind Speed': 6.33,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -13.25,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 80.65,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'CK',
#   'Current Description': 'light rain'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 67.28,
#   'Humidity': 68,
#   'Cloudiness': 4,
#   'Wind Speed': 7.52,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 56.8,
#   'Humidity': 56,
#   'Cloudiness': 62,
#   'Wind Speed': 7.14,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 56.48,
#   'Humidity': 41,
#   'Cloudiness': 32,
#   'Wind Speed': 3.38,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 77.54,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 9.01,
#   'Country': 'BS',
#   'Current Description': 'clear sky'},
#  {'City': 'Beyneu',
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Max Temp': 33.4,
#   'Humidity': 83,
#   'Cloudiness': 71,
#   'Wind Speed': 10.31,
#   'Country': 'KZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 58.86,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Country': 'AR',
#   'Current Description': 'light rain'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 65.01,
#   'Humidity': 76,
#   'Cloudiness': 64,
#   'Wind Speed': 5.06,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 3.42,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Poysdorf',
#   'Lat': 48.6667,
#   'Lng': 16.6333,
#   'Max Temp': 35.94,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 12.55,
#   'Country': 'AT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 63.1,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.69,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 60.46,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ouesso',
#   'Lat': 1.6136,
#   'Lng': 16.0517,
#   'Max Temp': 75.31,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'CG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 80.62,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 25.32,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 75.6,
#   'Humidity': 70,
#   'Cloudiness': 96,
#   'Wind Speed': 8.61,
#   'Country': 'CV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sosnovo-Ozerskoye',
#   'Lat': 52.5249,
#   'Lng': 111.5418,
#   'Max Temp': -3.93,
#   'Humidity': 95,
#   'Cloudiness': 80,
#   'Wind Speed': 7.87,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82.78,
#   'Humidity': 80,
#   'Cloudiness': 98,
#   'Wind Speed': 8.41,
#   'Country': 'PG',
#   'Current Description': 'light rain'},
#  {'City': 'Jand',
#   'Lat': 33.4299,
#   'Lng': 72.0193,
#   'Max Temp': 53.71,
#   'Humidity': 20,
#   'Cloudiness': 96,
#   'Wind Speed': 4.21,
#   'Country': 'PK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 39.36,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 36.78,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 59.11,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 36.57,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'light rain'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -0.38,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fort Beaufort',
#   'Lat': -32.7748,
#   'Lng': 26.6338,
#   'Max Temp': 66,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.85,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lalibela',
#   'Lat': 12.0333,
#   'Lng': 39.0333,
#   'Max Temp': 53.96,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 6.51,
#   'Country': 'ET',
#   'Current Description': 'clear sky'},
#  {'City': 'Marshalltown',
#   'Lat': 42.0494,
#   'Lng': -92.908,
#   'Max Temp': 41.04,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 71.31,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Aleksandrov Gay',
#   'Lat': 50.147,
#   'Lng': 48.5704,
#   'Max Temp': 23.05,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 11.12,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 21.7,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sukhinichi',
#   'Lat': 54.0999,
#   'Lng': 35.3425,
#   'Max Temp': 24.03,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.66,
#   'Country': 'RU',
#   'Current Description': 'snow'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 72.66,
#   'Humidity': 73,
#   'Cloudiness': 74,
#   'Wind Speed': 4.12,
#   'Country': 'MG',
#   'Current Description': 'broken clouds'},
#  {'City': 'Las Vegas',
#   'Lat': 36.175,
#   'Lng': -115.1372,
#   'Max Temp': 52.27,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Biu',
#   'Lat': 10.6129,
#   'Lng': 12.1946,
#   'Max Temp': 70.66,
#   'Humidity': 26,
#   'Cloudiness': 17,
#   'Wind Speed': 7.16,
#   'Country': 'NG',
#   'Current Description': 'few clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 61.81,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 13.27,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 31.91,
#   'Humidity': 90,
#   'Cloudiness': 47,
#   'Wind Speed': 8.77,
#   'Country': 'IT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 56.08,
#   'Humidity': 74,
#   'Cloudiness': 61,
#   'Wind Speed': 13.94,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'San Joaquin',
#   'Lat': 37.9333,
#   'Lng': -121.3011,
#   'Max Temp': 60.37,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Lazaro Cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 83.62,
#   'Humidity': 63,
#   'Cloudiness': 73,
#   'Wind Speed': 7.4,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 70.48,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 6.35,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 79.9,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'MY',
#   'Current Description': 'few clouds'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 58.03,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.59,
#   'Country': 'YE',
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 67.19,
#   'Humidity': 87,
#   'Cloudiness': 34,
#   'Wind Speed': 15.68,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 71.29,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moberly',
#   'Lat': 39.4184,
#   'Lng': -92.4382,
#   'Max Temp': 47.62,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.79,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 17.54,
#   'Country': 'PG',
#   'Current Description': 'moderate rain'},
#  {'City': 'Boyolangu',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 75.72,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 3.76,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -33.5,
#   'Humidity': 100,
#   'Cloudiness': 85,
#   'Wind Speed': 6.13,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 76.96,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 8.08,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kasongo-Lunda',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 71.58,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.11,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vangaindrano',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 74.25,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 6.67,
#   'Country': 'MG',
#   'Current Description': 'light rain'},
#  {'City': 'Central Point',
#   'Lat': 42.376,
#   'Lng': -122.9164,
#   'Max Temp': 48.42,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 50.11,
#   'Humidity': 41,
#   'Cloudiness': 2,
#   'Wind Speed': 3.15,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 66.09,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 4.5,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Monastyrshchina',
#   'Lat': 54.3496,
#   'Lng': 31.838,
#   'Max Temp': 29.35,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 12.73,
#   'Country': 'RU',
#   'Current Description': 'snow'},
#  {'City': 'Ambanja',
#   'Lat': -13.6833,
#   'Lng': 48.45,
#   'Max Temp': 74.88,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 2.51,
#   'Country': 'MG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 69.82,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 24,
#   'Country': 'AR',
#   'Current Description': 'few clouds'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 68.11,
#   'Humidity': 84,
#   'Cloudiness': 71,
#   'Wind Speed': 10.87,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tres Barras',
#   'Lat': -26.1064,
#   'Lng': -50.3222,
#   'Max Temp': 70.93,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Casper',
#   'Lat': 42.8666,
#   'Lng': -106.3131,
#   'Max Temp': 31.5,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 35.99,
#   'Country': 'US',
#   'Current Description': 'haze'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 52.45,
#   'Humidity': 53,
#   'Cloudiness': 5,
#   'Wind Speed': 0.38,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 76.53,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Country': 'GM',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 75.81,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -15.03,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 59.29,
#   'Humidity': 71,
#   'Cloudiness': 42,
#   'Wind Speed': 2.91,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Carreno',
#   'Lat': 6.189,
#   'Lng': -67.4859,
#   'Max Temp': 89.58,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'CO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 26.49,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 61.9,
#   'Humidity': 77,
#   'Cloudiness': 91,
#   'Wind Speed': 7.29,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.09,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'ZA',
#   'Current Description': 'few clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 3.47,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.71,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 66.97,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 10.09,
#   'Country': 'UY',
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 42.39,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 18.01,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 78.37,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lagunas',
#   'Lat': -5.2269,
#   'Lng': -75.6753,
#   'Max Temp': 83.3,
#   'Humidity': 73,
#   'Cloudiness': 91,
#   'Wind Speed': 1.41,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaka',
#   'Lat': 37.3482,
#   'Lng': 59.6143,
#   'Max Temp': 46.67,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58,
#   'Country': 'TM',
#   'Current Description': 'clear sky'},
#  {'City': 'Cantaura',
#   'Lat': 9.3057,
#   'Lng': -64.3584,
#   'Max Temp': 79.29,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'VE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 78.76,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Zavitinsk',
#   'Lat': 50.1167,
#   'Lng': 129.45,
#   'Max Temp': 8.8,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 82.56,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'TO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Stephenville',
#   'Lat': 32.2207,
#   'Lng': -98.2023,
#   'Max Temp': 53.94,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 80.69,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 17.76,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Irkutsk',
#   'Lat': 52.2978,
#   'Lng': 104.2964,
#   'Max Temp': 11.17,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 57.11,
#   'Humidity': 77,
#   'Cloudiness': 13,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'Boa Vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 80.58,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'Teshie',
#   'Lat': 5.5836,
#   'Lng': -0.1072,
#   'Max Temp': 84.76,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'GH',
#   'Current Description': 'clear sky'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 55.92,
#   'Humidity': 58,
#   'Cloudiness': 17,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'Ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 68.77,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 84.31,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'VU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Juneau',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp': 25.84,
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'fog'},
#  {'City': 'Rochegda',
#   'Lat': 62.8,
#   'Lng': 43.25,
#   'Max Temp': 9,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 7.36,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 79.47,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'VU',
#   'Current Description': 'light rain'},
#  {'City': 'Tayu',
#   'Lat': -6.5397,
#   'Lng': 111.0518,
#   'Max Temp': 77.22,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.27,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -11.31,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 4,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Abu Dhabi',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 73.96,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'AE',
#   'Current Description': 'few clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -41.75,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 2.19,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 57.67,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 8.34,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Sibiti',
#   'Lat': -3.6819,
#   'Lng': 13.3499,
#   'Max Temp': 70.03,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'CG',
#   'Current Description': 'light rain'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 43.27,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'IS',
#   'Current Description': 'broken clouds'},
#  {'City': 'Soyo',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 78.93,
#   'Humidity': 89,
#   'Cloudiness': 91,
#   'Wind Speed': 3.56,
#   'Country': 'AO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 29.07,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'NO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 12.25,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 28.4,
#   'Humidity': 82,
#   'Cloudiness': 47,
#   'Wind Speed': 14.85,
#   'Country': 'NO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sinop',
#   'Lat': 41.7711,
#   'Lng': 34.8709,
#   'Max Temp': 48.61,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Country': 'TR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 42.04,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 24.54,
#   'Country': 'IS',
#   'Current Description': 'light rain'},
#  {'City': 'Nenjiang',
#   'Lat': 49.1833,
#   'Lng': 125.2167,
#   'Max Temp': 10.56,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Noumea',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 87.78,
#   'Humidity': 99,
#   'Cloudiness': 77,
#   'Wind Speed': 0.96,
#   'Country': 'NC',
#   'Current Description': 'broken clouds'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': -11.87,
#   'Humidity': 91,
#   'Cloudiness': 81,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 44.33,
#   'Humidity': 84,
#   'Cloudiness': 93,
#   'Wind Speed': 27.22,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vinh',
#   'Lat': 18.6667,
#   'Lng': 105.6667,
#   'Max Temp': 65.03,
#   'Humidity': 94,
#   'Cloudiness': 53,
#   'Wind Speed': 6.91,
#   'Country': 'VN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 28.24,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'SJ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Indian Head',
#   'Lat': 38.6001,
#   'Lng': -77.1622,
#   'Max Temp': 70.14,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 80.49,
#   'Humidity': 79,
#   'Cloudiness': 48,
#   'Wind Speed': 6.64,
#   'Country': 'MV',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 69.01,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Chernushka',
#   'Lat': 56.5072,
#   'Lng': 56.0766,
#   'Max Temp': 8.15,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 6.17,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -3.35,
#   'Humidity': 65,
#   'Cloudiness': 11,
#   'Wind Speed': 7.31,
#   'Country': 'GL',
#   'Current Description': 'few clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 69.48,
#   'Humidity': 74,
#   'Cloudiness': 4,
#   'Wind Speed': 8.52,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 77.11,
#   'Humidity': 48,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 77.34,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'LK',
#   'Current Description': 'clear sky'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 80.58,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 79.68,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ondangwa',
#   'Lat': -17.9167,
#   'Lng': 15.95,
#   'Max Temp': 74.32,
#   'Humidity': 64,
#   'Cloudiness': 27,
#   'Wind Speed': 11.12,
#   'Country': 'NA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 78.84,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 16.42,
#   'Country': 'NC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 82.29,
#   'Humidity': 65,
#   'Cloudiness': 85,
#   'Wind Speed': 4.61,
#   'Country': 'NU',
#   'Current Description': 'light rain'},
#  {'City': 'Klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 14.72,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.14,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nyurba',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': -30.06,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nicoya',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 89.15,
#   'Humidity': 63,
#   'Cloudiness': 12,
#   'Wind Speed': 3.22,
#   'Country': 'CR',
#   'Current Description': 'few clouds'},
#  {'City': 'Manacapuru',
#   'Lat': -3.2997,
#   'Lng': -60.6206,
#   'Max Temp': 77.58,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 1.07,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Verkhoyansk',
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp': -29.24,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 1.81,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 77.09,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 75.07,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 15.01,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhiryatino',
#   'Lat': 53.2228,
#   'Lng': 33.7306,
#   'Max Temp': 30.52,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.62,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 18.28,
#   'Humidity': 57,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -0.4,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 77.09,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'GF',
#   'Current Description': 'light rain'},
#  {'City': 'Voh',
#   'Lat': -20.9667,
#   'Lng': 164.7,
#   'Max Temp': 84.67,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 4.63,
#   'Country': 'NC',
#   'Current Description': 'light rain'},
#  {'City': 'Novoagansk',
#   'Lat': 61.9449,
#   'Lng': 76.6625,
#   'Max Temp': 3.34,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 69.87,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 74.79,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 12.01,
#   'Country': 'RE',
#   'Current Description': 'light rain'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.58,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 16.73,
#   'Country': 'KI',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -14.67,
#   'Humidity': 85,
#   'Cloudiness': 11,
#   'Wind Speed': 8.3,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Mayo',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 71.58,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Benton Harbor',
#   'Lat': 42.1167,
#   'Lng': -86.4542,
#   'Max Temp': 40.32,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 21.85,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 78.22,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 56.98,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 2.33,
#   'Country': 'ES',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Poso',
#   'Lat': -1.3959,
#   'Lng': 120.7524,
#   'Max Temp': 76.48,
#   'Humidity': 87,
#   'Cloudiness': 82,
#   'Wind Speed': 3.47,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': -7.53,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Acarau',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 81.1,
#   'Humidity': 77,
#   'Cloudiness': 3,
#   'Wind Speed': 16.82,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Vrangel',
#   'Lat': 42.7297,
#   'Lng': 133.0839,
#   'Max Temp': 34.65,
#   'Humidity': 66,
#   'Cloudiness': 52,
#   'Wind Speed': 18.01,
#   'Country': 'RU',
#   'Current Description': 'moderate rain'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 64.81,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 33.35,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 16.08,
#   'Country': 'RU',
#   'Current Description': 'snow'},
#  {'City': 'Mao',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 52.36,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'ES',
#   'Current Description': 'clear sky'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': -8.41,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 8.7,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Zlatoust',
#   'Lat': 55.1711,
#   'Lng': 59.6508,
#   'Max Temp': 4.59,
#   'Humidity': 95,
#   'Cloudiness': 10,
#   'Wind Speed': 2.89,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'North Myrtle Beach',
#   'Lat': 33.816,
#   'Lng': -78.68,
#   'Max Temp': 77.29,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 15.82,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Balkanabat',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 49.24,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'TM',
#   'Current Description': 'clear sky'},
#  {'City': 'Playa Del Carmen',
#   'Lat': 20.6274,
#   'Lng': -87.0799,
#   'Max Temp': 85.95,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 64.81,
#   'Humidity': 29,
#   'Cloudiness': 99,
#   'Wind Speed': 17.16,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Luganville',
#   'Lat': -15.5333,
#   'Lng': 167.1667,
#   'Max Temp': 84.16,
#   'Humidity': 76,
#   'Cloudiness': 95,
#   'Wind Speed': 6.78,
#   'Country': 'VU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Roseburg',
#   'Lat': 43.2165,
#   'Lng': -123.3417,
#   'Max Temp': 50.67,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Robertsport',
#   'Lat': 6.7533,
#   'Lng': -11.3686,
#   'Max Temp': 82.04,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 9.91,
#   'Country': 'LR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jining',
#   'Lat': 35.405,
#   'Lng': 116.5814,
#   'Max Temp': 44.85,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 11.54,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 47.1,
#   'Humidity': 79,
#   'Cloudiness': 13,
#   'Wind Speed': 11.79,
#   'Country': 'JP',
#   'Current Description': 'few clouds'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 79.41,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Country': 'BB',
#   'Current Description': 'few clouds'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 48.92,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 77.76,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 80.56,
#   'Humidity': 84,
#   'Cloudiness': 45,
#   'Wind Speed': 7,
#   'Country': 'GH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Uvira',
#   'Lat': -3.4067,
#   'Lng': 29.1458,
#   'Max Temp': 74.57,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Country': 'CD',
#   'Current Description': 'light rain'},
#  {'City': 'Selma',
#   'Lat': 36.5708,
#   'Lng': -119.6121,
#   'Max Temp': 61.02,
#   'Humidity': 71,
#   'Cloudiness': 46,
#   'Wind Speed': 2.46,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kendallville',
#   'Lat': 41.4414,
#   'Lng': -85.265,
#   'Max Temp': 37.65,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 64,
#   'Humidity': 77,
#   'Cloudiness': 95,
#   'Wind Speed': 2.53,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 76.1,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Diu',
#   'Lat': 20.7141,
#   'Lng': 70.9822,
#   'Max Temp': 72.99,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 8.3,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 82.87,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.66,
#   'Country': 'SB',
#   'Current Description': 'moderate rain'},
#  {'City': 'Bucerias',
#   'Lat': 20.75,
#   'Lng': -105.3333,
#   'Max Temp': 80.58,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 49.75,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Heiligenhafen',
#   'Lat': 54.3667,
#   'Lng': 10.9833,
#   'Max Temp': 38.82,
#   'Humidity': 93,
#   'Cloudiness': 80,
#   'Wind Speed': 8.57,
#   'Country': 'DE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 69.67,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 5.88,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pampa',
#   'Lat': 35.5362,
#   'Lng': -100.9599,
#   'Max Temp': 50.04,
#   'Humidity': 17,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 55.26,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Beidao',
#   'Lat': 34.5686,
#   'Lng': 105.8933,
#   'Max Temp': 29.95,
#   'Humidity': 77,
#   'Cloudiness': 52,
#   'Wind Speed': 0.89,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pemangkat',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 77.38,
#   'Humidity': 89,
#   'Cloudiness': 70,
#   'Wind Speed': 6.08,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -25.64,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 1.36,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 79.9,
#   'Humidity': 64,
#   'Cloudiness': 42,
#   'Wind Speed': 8.01,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 55.45,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 53.44,
#   'Humidity': 71,
#   'Cloudiness': 36,
#   'Wind Speed': 13.67,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wageningen',
#   'Lat': 51.9667,
#   'Lng': 5.6667,
#   'Max Temp': 42.94,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'NL',
#   'Current Description': 'mist'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 68.32,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'HK',
#   'Current Description': 'clear sky'},
#  {'City': 'Yulin',
#   'Lat': 22.6333,
#   'Lng': 110.15,
#   'Max Temp': 63.81,
#   'Humidity': 65,
#   'Cloudiness': 25,
#   'Wind Speed': 2.86,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 27.05,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 24.65,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 83.03,
#   'Humidity': 63,
#   'Cloudiness': 4,
#   'Wind Speed': 18.59,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 39.76,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -2.16,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 60.31,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 74.55,
#   'Humidity': 92,
#   'Cloudiness': 18,
#   'Wind Speed': 5.46,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Boffa',
#   'Lat': 10.1667,
#   'Lng': -14.0333,
#   'Max Temp': 79.5,
#   'Humidity': 82,
#   'Cloudiness': 82,
#   'Wind Speed': 2.64,
#   'Country': 'GN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.07,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 4.65,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -0.4,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tecate',
#   'Lat': 32.5667,
#   'Lng': -116.6333,
#   'Max Temp': 66.6,
#   'Humidity': 24,
#   'Cloudiness': 2,
#   'Wind Speed': 3.29,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 75.04,
#   'Humidity': 25,
#   'Cloudiness': 91,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arona',
#   'Lat': 28.0996,
#   'Lng': -16.681,
#   'Max Temp': 63.39,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'Boves',
#   'Lat': 44.332,
#   'Lng': 7.5514,
#   'Max Temp': 44.44,
#   'Humidity': 44,
#   'Cloudiness': 4,
#   'Wind Speed': 5.5,
#   'Country': 'IT',
#   'Current Description': 'clear sky'},
#  {'City': 'Lewiston',
#   'Lat': 44.1003,
#   'Lng': -70.2148,
#   'Max Temp': 47.66,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'Kristianstad',
#   'Lat': 56.0313,
#   'Lng': 14.1524,
#   'Max Temp': 33.55,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'SE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 59.72,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -27.38,
#   'Humidity': 91,
#   'Cloudiness': 43,
#   'Wind Speed': 7.4,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -3.84,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Kambove',
#   'Lat': -10.8764,
#   'Lng': 26.5969,
#   'Max Temp': 66.76,
#   'Humidity': 65,
#   'Cloudiness': 45,
#   'Wind Speed': 3.83,
#   'Country': 'CD',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Doctor Phillips',
#   'Lat': 28.4495,
#   'Lng': -81.4923,
#   'Max Temp': 84.31,
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nieuw Amsterdam',
#   'Lat': 5.8833,
#   'Lng': -55.0833,
#   'Max Temp': 82.56,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'SR',
#   'Current Description': 'few clouds'},
#  {'City': 'Mocajuba',
#   'Lat': -2.5842,
#   'Lng': -49.5072,
#   'Max Temp': 77.97,
#   'Humidity': 87,
#   'Cloudiness': 38,
#   'Wind Speed': 2.89,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 50.14,
#   'Humidity': 68,
#   'Cloudiness': 63,
#   'Wind Speed': 12.62,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 55.92,
#   'Humidity': 49,
#   'Cloudiness': 52,
#   'Wind Speed': 5.12,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 43.2,
#   'Humidity': 62,
#   'Cloudiness': 67,
#   'Wind Speed': 10.49,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ojinaga',
#   'Lat': 29.5667,
#   'Lng': -104.4167,
#   'Max Temp': 67.57,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 80.85,
#   'Humidity': 75,
#   'Cloudiness': 60,
#   'Wind Speed': 13.78,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 12.45,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 10.56,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -45.17,
#   'Humidity': 100,
#   'Cloudiness': 41,
#   'Wind Speed': 4.25,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Evensk',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': -8.7,
#   'Humidity': 70,
#   'Cloudiness': 26,
#   'Wind Speed': 9.86,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 80.04,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 8.63,
#   'Country': 'CI',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Limbang',
#   'Lat': 4.75,
#   'Lng': 115,
#   'Max Temp': 77.31,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 1.19,
#   'Country': 'MY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Adur',
#   'Lat': 9.1667,
#   'Lng': 76.7333,
#   'Max Temp': 71.89,
#   'Humidity': 89,
#   'Cloudiness': 12,
#   'Wind Speed': 2.71,
#   'Country': 'IN',
#   'Current Description': 'few clouds'},
#  {'City': 'Rettikhovka',
#   'Lat': 44.1683,
#   'Lng': 132.7669,
#   'Max Temp': 25.48,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 7.16,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 59.58,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 68.59,
#   'Humidity': 67,
#   'Cloudiness': 12,
#   'Wind Speed': 10.2,
#   'Country': 'UY',
#   'Current Description': 'few clouds'},
#  {'City': 'Mandera',
#   'Lat': 3.9366,
#   'Lng': 41.867,
#   'Max Temp': 82.65,
#   'Humidity': 33,
#   'Cloudiness': 4,
#   'Wind Speed': 7,
#   'Country': 'KE',
#   'Current Description': 'clear sky'},
#  {'City': 'Melito Di Porto Salvo',
#   'Lat': 37.9222,
#   'Lng': 15.7714,
#   'Max Temp': 55.29,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'IT',
#   'Current Description': 'moderate rain'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 75.38,
#   'Humidity': 77,
#   'Cloudiness': 47,
#   'Wind Speed': 4,
#   'Country': 'VE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 61.9,
#   'Humidity': 83,
#   'Cloudiness': 32,
#   'Wind Speed': 4.03,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -3.77,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 28.99,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
# ...
#   'Wind Speed': 13,
#   'Country': 'ES',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ust-Charyshskaya Pristan',
#   'Lat': 52.3934,
#   'Lng': 83.6635,
#   'Max Temp': 8.29,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Loandjili',
#   'Lat': -4.7561,
#   'Lng': 11.8578,
#   'Max Temp': 77.11,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CG',
#   'Current Description': 'thunderstorm with light rain'},
#  {'City': 'Diamantino',
#   'Lat': -14.4086,
#   'Lng': -56.4461,
#   'Max Temp': 77.02,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'BR',
#   'Current Description': 'moderate rain'},
#  {'City': 'Nassau',
#   'Lat': 40.7507,
#   'Lng': -73.5829,
#   'Max Temp': 66.88,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'Ayagoz',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': -3.64,
#   'Humidity': 84,
#   'Cloudiness': 87,
#   'Wind Speed': 3.83,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -36.49,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 0.74,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 57.94,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yurimaguas',
#   'Lat': -5.9,
#   'Lng': -76.0833,
#   'Max Temp': 82.56,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'PE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mayna',
#   'Lat': 54.1135,
#   'Lng': 47.6231,
#   'Max Temp': 16.29,
#   'Humidity': 75,
#   'Cloudiness': 5,
#   'Wind Speed': 9.93,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 67.91,
#   'Humidity': 18,
#   'Cloudiness': 82,
#   'Wind Speed': 10.22,
#   'Country': 'ML',
#   'Current Description': 'broken clouds'},
#  {'City': 'Darnah',
#   'Lat': 32.767,
#   'Lng': 22.6367,
#   'Max Temp': 59.79,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 20.36,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'Masallatah',
#   'Lat': 32.6167,
#   'Lng': 14,
#   'Max Temp': 56.57,
#   'Humidity': 56,
#   'Cloudiness': 96,
#   'Wind Speed': 20.51,
#   'Country': 'LY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Velho',
#   'Lat': -8.7619,
#   'Lng': -63.9039,
#   'Max Temp': 86.05,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Neuquen',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 80.49,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Soderhamn',
#   'Lat': 61.3037,
#   'Lng': 17.0592,
#   'Max Temp': 34.39,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Country': 'SE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Constanza',
#   'Lat': 47.6603,
#   'Lng': 9.1758,
#   'Max Temp': 38.07,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Country': 'DE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Killarney',
#   'Lat': 52.05,
#   'Lng': -9.5167,
#   'Max Temp': 51.98,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'IE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gambela',
#   'Lat': 8.25,
#   'Lng': 34.5833,
#   'Max Temp': 79.75,
#   'Humidity': 36,
#   'Cloudiness': 4,
#   'Wind Speed': 3.78,
#   'Country': 'ET',
#   'Current Description': 'clear sky'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 67.95,
#   'Humidity': 16,
#   'Cloudiness': 79,
#   'Wind Speed': 10.18,
#   'Country': 'MR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rakaia',
#   'Lat': -43.75,
#   'Lng': 172.0167,
#   'Max Temp': 56.75,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kirovskiy',
#   'Lat': 45.0917,
#   'Lng': 133.5136,
#   'Max Temp': 20.75,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'West Bay',
#   'Lat': 19.3667,
#   'Lng': -81.4167,
#   'Max Temp': 86.07,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'KY',
#   'Current Description': 'few clouds'},
#  {'City': 'Lexington',
#   'Lat': 37.9887,
#   'Lng': -84.4777,
#   'Max Temp': 40.89,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 76.89,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 6.6,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mount Pleasant',
#   'Lat': 32.7941,
#   'Lng': -79.8626,
#   'Max Temp': 77.18,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Chara',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': -21.39,
#   'Humidity': 73,
#   'Cloudiness': 71,
#   'Wind Speed': 2.33,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Windhoek',
#   'Lat': -22.5594,
#   'Lng': 17.0832,
#   'Max Temp': 76.1,
#   'Humidity': 20,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'NA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 23.88,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'GL',
#   'Current Description': 'light snow'},
#  {'City': 'Aanekoski',
#   'Lat': 62.6946,
#   'Lng': 25.818,
#   'Max Temp': 24.87,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.07,
#   'Country': 'FI',
#   'Current Description': 'light snow'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 77.56,
#   'Humidity': 91,
#   'Cloudiness': 93,
#   'Wind Speed': 9.91,
#   'Country': 'GF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Magadan',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': 14.59,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.9,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pasinler',
#   'Lat': 39.9803,
#   'Lng': 41.6764,
#   'Max Temp': 22.19,
#   'Humidity': 60,
#   'Cloudiness': 56,
#   'Wind Speed': 2.93,
#   'Country': 'TR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Novyy Urengoy',
#   'Lat': 66.0833,
#   'Lng': 76.6333,
#   'Max Temp': -12.64,
#   'Humidity': 98,
#   'Cloudiness': 57,
#   'Wind Speed': 9.01,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Fuerte Olimpo',
#   'Lat': -21.0415,
#   'Lng': -57.8738,
#   'Max Temp': 94.21,
#   'Humidity': 33,
#   'Cloudiness': 94,
#   'Wind Speed': 8.01,
#   'Country': 'PY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bereda',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 51.55,
#   'Humidity': 97,
#   'Cloudiness': 61,
#   'Wind Speed': 0.98,
#   'Country': 'ES',
#   'Current Description': 'broken clouds'},
#  {'City': 'Fairmont',
#   'Lat': 39.4851,
#   'Lng': -80.1426,
#   'Max Temp': 61.38,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Taldan',
#   'Lat': 53.6667,
#   'Lng': 124.8,
#   'Max Temp': 0.9,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 7.36,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 13.57,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rancho Palos Verdes',
#   'Lat': 33.7445,
#   'Lng': -118.387,
#   'Max Temp': 70.66,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Mahajanga',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 80.62,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'MG',
#   'Current Description': 'few clouds'},
#  {'City': 'Ranong',
#   'Lat': 9.9658,
#   'Lng': 98.6348,
#   'Max Temp': 73.58,
#   'Humidity': 89,
#   'Cloudiness': 25,
#   'Wind Speed': 4.29,
#   'Country': 'TH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chicama',
#   'Lat': -7.8447,
#   'Lng': -79.1469,
#   'Max Temp': 64.94,
#   'Humidity': 67,
#   'Cloudiness': 46,
#   'Wind Speed': 9.04,
#   'Country': 'PE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'West Plains',
#   'Lat': 36.7281,
#   'Lng': -91.8524,
#   'Max Temp': 46.09,
#   'Humidity': 43,
#   'Cloudiness': 28,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hasilpur',
#   'Lat': 29.7122,
#   'Lng': 72.5553,
#   'Max Temp': 58.62,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Country': 'PK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Abnub',
#   'Lat': 27.2696,
#   'Lng': 31.1511,
#   'Max Temp': 61.02,
#   'Humidity': 29,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'EG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Amahai',
#   'Lat': -3.3333,
#   'Lng': 128.9167,
#   'Max Temp': 79.57,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Budhlada',
#   'Lat': 29.9333,
#   'Lng': 75.5667,
#   'Max Temp': 56.71,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 65.39,
#   'Humidity': 42,
#   'Cloudiness': 62,
#   'Wind Speed': 1.54,
#   'Country': 'IL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 83.88,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'GD',
#   'Current Description': 'few clouds'},
#  {'City': 'Magway',
#   'Lat': 20.15,
#   'Lng': 94.9167,
#   'Max Temp': 70.18,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 3.76,
#   'Country': 'MM',
#   'Current Description': 'clear sky'},
#  {'City': 'Terney',
#   'Lat': 45.0503,
#   'Lng': 136.6092,
#   'Max Temp': 27.36,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 5.21,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 65.75,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 27.22,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 42.33,
#   'Humidity': 93,
#   'Cloudiness': 6,
#   'Wind Speed': 4.12,
#   'Country': 'PT',
#   'Current Description': 'clear sky'},
#  {'City': 'Prado',
#   'Lat': -17.3411,
#   'Lng': -39.2208,
#   'Max Temp': 75.51,
#   'Humidity': 91,
#   'Cloudiness': 8,
#   'Wind Speed': 7.4,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 18.32,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 13.94,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ayr',
#   'Lat': 55.4627,
#   'Lng': -4.6339,
#   'Max Temp': 50.09,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'GB',
#   'Current Description': 'few clouds'},
#  {'City': 'Khonsa',
#   'Lat': 27.0167,
#   'Lng': 95.5667,
#   'Max Temp': 50.27,
#   'Humidity': 93,
#   'Cloudiness': 14,
#   'Wind Speed': 3.83,
#   'Country': 'IN',
#   'Current Description': 'few clouds'},
#  {'City': 'Talara',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 72.36,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 61.9,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Malkangiri',
#   'Lat': 18.35,
#   'Lng': 81.9,
#   'Max Temp': 66.7,
#   'Humidity': 81,
#   'Cloudiness': 31,
#   'Wind Speed': 2.24,
#   'Country': 'IN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gavrilovka Vtoraya',
#   'Lat': 52.877,
#   'Lng': 42.7663,
#   'Max Temp': 23.31,
#   'Humidity': 52,
#   'Cloudiness': 2,
#   'Wind Speed': 8.61,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 79.41,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dunmore Town',
#   'Lat': 25.5,
#   'Lng': -76.65,
#   'Max Temp': 77.99,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 14.27,
#   'Country': 'BS',
#   'Current Description': 'clear sky'},
#  {'City': 'Barkhan',
#   'Lat': 29.8977,
#   'Lng': 69.5256,
#   'Max Temp': 46.36,
#   'Humidity': 31,
#   'Cloudiness': 92,
#   'Wind Speed': 2.86,
#   'Country': 'PK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kawambwa',
#   'Lat': -9.7915,
#   'Lng': 29.0791,
#   'Max Temp': 67.37,
#   'Humidity': 63,
#   'Cloudiness': 63,
#   'Wind Speed': 4.76,
#   'Country': 'ZM',
#   'Current Description': 'broken clouds'},
#  {'City': 'Minsk',
#   'Lat': 53.9,
#   'Lng': 27.5667,
#   'Max Temp': 35.35,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Country': 'BY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ryotsu',
#   'Lat': 38.0833,
#   'Lng': 138.4333,
#   'Max Temp': 46.36,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 11.56,
#   'Country': 'JP',
#   'Current Description': 'light rain'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 70.43,
#   'Humidity': 12,
#   'Cloudiness': 34,
#   'Wind Speed': 10.51,
#   'Country': 'ML',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 76.73,
#   'Humidity': 81,
#   'Cloudiness': 42,
#   'Wind Speed': 21.77,
#   'Country': 'SO',
#   'Current Description': 'light rain'},
#  {'City': 'Manitouwadge',
#   'Lat': 49.1215,
#   'Lng': -85.8403,
#   'Max Temp': 26.38,
#   'Humidity': 88,
#   'Cloudiness': 92,
#   'Wind Speed': 8.72,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Launceston',
#   'Lat': -41.45,
#   'Lng': 147.1667,
#   'Max Temp': 60.62,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Reo',
#   'Lat': 12.3167,
#   'Lng': -2.4667,
#   'Max Temp': 78.76,
#   'Humidity': 16,
#   'Cloudiness': 83,
#   'Wind Speed': 7.74,
#   'Country': 'BF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nistoresti',
#   'Lat': 45.8333,
#   'Lng': 26.7333,
#   'Max Temp': 46.17,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'RO',
#   'Current Description': 'light rain'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 67.78,
#   'Humidity': 59,
#   'Cloudiness': 19,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Dalaba',
#   'Lat': 10.7,
#   'Lng': -12.25,
#   'Max Temp': 64.67,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'GN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pecos',
#   'Lat': 31.4229,
#   'Lng': -103.4932,
#   'Max Temp': 54.3,
#   'Humidity': 13,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'New Bern',
#   'Lat': 35.1085,
#   'Lng': -77.0441,
#   'Max Temp': 74.35,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 70.23,
#   'Humidity': 84,
#   'Cloudiness': 67,
#   'Wind Speed': 11.01,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 79.14,
#   'Humidity': 83,
#   'Cloudiness': 29,
#   'Wind Speed': 7.61,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Khatanga  71.9667  102.5000    -43.65       100          58        4.36
# 1    Atuona  -9.8000 -139.0333     79.21        71          66       17.92
# 2   Isabela   6.7085  121.9711     77.05        88          89        4.88
# 3    Hobart -42.8794  147.3294     56.26        68          75        5.75
# 4   Rikitea -23.1203 -134.9692     76.06        75          92       16.13
# 5  Holetown  13.1867  -59.6381     79.36        80          80       19.35
# 6   Camacha  33.0833  -16.3333     61.54        88          40       12.66
# 7   Mazagao  -0.1150  -51.2894     86.05        74          58        6.33
# 8     Tiksi  71.6872  128.8694    -13.25        98         100        4.25
# 9    Avarua -21.2078 -159.7750     80.65        74          20       16.11
#
#   Country Current Description
# 0      RU       broken clouds
# 1      PF       broken clouds
# 2      PH     overcast clouds
# 3      AU       broken clouds
# 4      PF     overcast clouds
# 5      BB       broken clouds
# 6      PT             drizzle
# 7      BR       broken clouds
# 8      RU     overcast clouds
# 9      CK          light rain

# %%
len(city_data)
# Out:
# 719

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga      RU  71.9667  102.5000    -43.65       100          58
# 1        Atuona      PF  -9.8000 -139.0333     79.21        71          66
# 2       Isabela      PH   6.7085  121.9711     77.05        88          89
# 3        Hobart      AU -42.8794  147.3294     56.26        68          75
# 4       Rikitea      PF -23.1203 -134.9692     76.06        75          92
# ..          ...     ...      ...       ...       ...       ...         ...
# 714      Dalaba      GN  10.7000  -12.2500     64.67        35         100
# 715       Pecos      US  31.4229 -103.4932     54.30        13           1
# 716    New Bern      US  35.1085  -77.0441     74.35        88         100
# 717     Wanning      CN  18.8003  110.3967     70.23        84          67
# 718  Carutapera      BR  -1.1950  -46.0200     79.14        83          29
#
#      Wind Speed Current Description
# 0          4.36       broken clouds
# 1         17.92       broken clouds
# 2          4.88     overcast clouds
# 3          5.75       broken clouds
# 4         16.13     overcast clouds
# ..          ...                 ...
# 714        1.59     overcast clouds
# 715        3.44           clear sky
# 716        4.00     overcast clouds
# 717       11.01       broken clouds
# 718        7.61    scattered clouds
#
# [719 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
